# %% [markdown]
# <a href="https://colab.research.google.com/github/jo-alves01/hello-world/blob/master/rascunho_rna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sys
import matplotlib.pyplot as plt

# %%
data = np.fromfile("dataAll.txt")
np.set_printoptions(threshold=sys.maxsize)
len(data)
# Out:
# 3000

# %%
data_split = np.split(data, 1000)
len(data_split)
# Out:
# 1000

# %%
j=0
for j in range (5):
    print(data_split[j])
# Out:
# [-363.7884  244.1423    0.    ]
# [ 328.7572 -256.7658    1.    ]
# [-164.9827  613.2164    0.    ]
# [536.5905 764.9575   0.    ]
# [314.2297 343.8375   0.    ]

# %%
fig, ax = plt.subplots(figsize=(15, 15))

i=0
for i in range (len(data_split)):
    x = data_split[i][0]
    #print(data_split[i][0])
    y = data_split[i][1]
    #print(data_split[i][1])
    #print(data_split[i][2])
    if data_split[i][2] < 1:
        y_blue = data_split[i][1]
        plt.scatter(x,y_blue, c='blue')
    else:
        y_red = data_split[i][1]
        plt.scatter(x, y_red, c='red')
